# %%
import pandas as pd
import seaborn as sns
import numpy as np
import folium
import re

import matplotlib
import matplotlib.pyplot as plt
from matplotlib import font_manager, rc
from wordcloud import WordCloud

from datetime import datetime
import time

# %%
font_path = 'C:/windows/fonts/NanumBarunpenB.ttf'
font_name = font_manager.FontProperties(fname=font_path).get_name()
rc('font', family=font_name)

# %%
# 글자 선명
from IPython.display import set_matplotlib_formats

set_matplotlib_formats("retina")
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_13208\141453295.py:4: DeprecationWarning: `set_matplotlib_formats` is deprecated since IPython 7.23, directly use `matplotlib_inline.backend_inline.set_matplotlib_formats()`
#   set_matplotlib_formats("retina")

# %% [markdown]
# #### 주유소 위경도 csv 파일 불러오기

# %%
df = pd.read_csv('./data/주유소 위경도.csv', encoding='utf-8')
df.head()
# Out:
#                상호                      주소                     Unnamed: 2
# 0      (주)개금태화주유소        부산 부산진구 가야대로 402  X :129.016910, Y :35.1514817
# 1         (주)경인석유     부산 남구 신선로 448 (용당동)   X :129.100468, Y :35.1248122
# 2        (주)경인에너지     부산 강서구 생곡로 40 (녹산동)   X :128.897647, Y :35.1248039
# 3      (주)고리길천주유소     부산 기장군 장안읍 해맞이로 487   X :129.289381, Y :35.3315196
# 4  (주)나부코직영 우원주유소  부산 영도구 태종로 181 (봉래동4가)   X :129.047706, Y :35.0948319

# %% [markdown]
# #### 컬럼 값이 없는 것을 위경도로 설정해준다, 값이 없는 392,393 행 제거

# %%
df.rename(columns={'Unnamed: 2' : '위경도'}, inplace=True)
df = df.drop(index=392, axis=0)
df = df.drop(index=393, axis=0)
df
# Out:
#                       상호                      주소  \
# 0             (주)개금태화주유소        부산 부산진구 가야대로 402
# 1                (주)경인석유     부산 남구 신선로 448 (용당동)
# 2               (주)경인에너지     부산 강서구 생곡로 40 (녹산동)
# 3             (주)고리길천주유소     부산 기장군 장안읍 해맞이로 487
# 4         (주)나부코직영 우원주유소  부산 영도구 태종로 181 (봉래동4가)
# ..                   ...                     ...
# 387      SK에너지(주)신광셀프주유소     부산 북구 덕천로 275 (만덕동)
# 388       SK에너지(주)신도시주유소     부산 해운대구 대천로 82 (좌동)
# 389    SK에너지(주)직영 태종로주유소    부산 영도구 태종로 290 (청학동)
# 390  SK에너지(주)직영 해운대센텀주유소      부산 해운대구 수영강변대로 276
# 391             YK에너지(주)     부산 남구 신선로 387 (용당동)
#
#                                위경도
# 0    X :129.016910, Y :35.1514817
# 1     X :129.100468, Y :35.1248122
# 2     X :128.897647, Y :35.1248039
# 3     X :129.289381, Y :35.3315196
# 4     X :129.047706, Y :35.0948319
# ..                             ...
# 387   X :129.034087, Y :35.2098781
# 388   X :129.171720, Y :35.1735968
# 389   X :129.057642, Y :35.0979530
# 390  X :129.119134, Y :35.1835484
# 391  X :129.097491, Y :35.1203309
#
# [392 rows x 3 columns]

# %% [markdown]
# #### 경도 컬럼에 위경도의 값들을 ,로 둘로 나누고 i번째의 0번째의 값을 가져온다

# %%
df['경도'] = 0

for i in df.index:
    df['경도'][i] = df['위경도'].str.split(',')[i][0]

df
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_13208\2673356394.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['경도'][i] = df['위경도'].str.split(',')[i][0]
#                       상호                      주소  \
# 0             (주)개금태화주유소        부산 부산진구 가야대로 402
# 1                (주)경인석유     부산 남구 신선로 448 (용당동)
# 2               (주)경인에너지     부산 강서구 생곡로 40 (녹산동)
# 3             (주)고리길천주유소     부산 기장군 장안읍 해맞이로 487
# 4         (주)나부코직영 우원주유소  부산 영도구 태종로 181 (봉래동4가)
# ..                   ...                     ...
# 387      SK에너지(주)신광셀프주유소     부산 북구 덕천로 275 (만덕동)
# 388       SK에너지(주)신도시주유소     부산 해운대구 대천로 82 (좌동)
# 389    SK에너지(주)직영 태종로주유소    부산 영도구 태종로 290 (청학동)
# 390  SK에너지(주)직영 해운대센텀주유소      부산 해운대구 수영강변대로 276
# 391             YK에너지(주)     부산 남구 신선로 387 (용당동)
#
#                                위경도             경도
# 0    X :129.016910, Y :35.1514817   X :129.016910
# 1     X :129.100468, Y :35.1248122  X :129.100468
# 2     X :128.897647, Y :35.1248039  X :128.897647
# 3     X :129.289381, Y :35.3315196  X :129.289381
# 4     X :129.047706, Y :35.0948319  X :129.047706
# ..                             ...            ...
# 387   X :129.034087, Y :35.2098781  X :129.034087
# 388   X :129.171720, Y :35.1735968  X :129.171720
# 389   X :129.057642, Y :35.0979530  X :129.057642
# 390  X :129.119134, Y :35.1835484   X :129.119134
# 391  X :129.097491, Y :35.1203309   X :129.097491
#
# [392 rows x 4 columns]

# %% [markdown]
# #### 위도 컬럼에 위경도의 값들을 ,로 둘로 나누고 i번째의 0번째의 값을 가져온다

# %%
df['위도'] = 0

for i in df.index:
    df['위도'][i] = (df['위경도'].str.split(',')[i][1])
df
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_13208\3340694080.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['위도'][i] = (df['위경도'].str.split(',')[i][1])
#                       상호                      주소  \
# 0             (주)개금태화주유소        부산 부산진구 가야대로 402
# 1                (주)경인석유     부산 남구 신선로 448 (용당동)
# 2               (주)경인에너지     부산 강서구 생곡로 40 (녹산동)
# 3             (주)고리길천주유소     부산 기장군 장안읍 해맞이로 487
# 4         (주)나부코직영 우원주유소  부산 영도구 태종로 181 (봉래동4가)
# ..                   ...                     ...
# 387      SK에너지(주)신광셀프주유소     부산 북구 덕천로 275 (만덕동)
# 388       SK에너지(주)신도시주유소     부산 해운대구 대천로 82 (좌동)
# 389    SK에너지(주)직영 태종로주유소    부산 영도구 태종로 290 (청학동)
# 390  SK에너지(주)직영 해운대센텀주유소      부산 해운대구 수영강변대로 276
# 391             YK에너지(주)     부산 남구 신선로 387 (용당동)
#
#                                위경도             경도               위도
# 0    X :129.016910, Y :35.1514817   X :129.016910   Y :35.1514817
# 1     X :129.100468, Y :35.1248122  X :129.100468    Y :35.1248122
# 2     X :128.897647, Y :35.1248039  X :128.897647    Y :35.1248039
# 3     X :129.289381, Y :35.3315196  X :129.289381    Y :35.3315196
# 4     X :129.047706, Y :35.0948319  X :129.047706    Y :35.0948319
# ..                             ...            ...              ...
# 387   X :129.034087, Y :35.2098781  X :129.034087    Y :35.2098781
# 388   X :129.171720, Y :35.1735968  X :129.171720    Y :35.1735968
# 389   X :129.057642, Y :35.0979530  X :129.057642    Y :35.0979530
# 390  X :129.119134, Y :35.1835484   X :129.119134   Y :35.1835484
# 391  X :129.097491, Y :35.1203309   X :129.097491   Y :35.1203309
#
# [392 rows x 5 columns]

# %% [markdown]
# #### 경도, 위도 컬럼 값들중 필요없는 (X :, Y :)을 공백으로 변환

# %%
df['경도'] = df['경도'].str.replace('X :', '')
df['위도'] = df['위도'].str.replace('Y :', '')
df.head()
# Out:
#                상호                      주소                            위경도  \
# 0      (주)개금태화주유소        부산 부산진구 가야대로 402  X :129.016910, Y :35.1514817
# 1         (주)경인석유     부산 남구 신선로 448 (용당동)   X :129.100468, Y :35.1248122
# 2        (주)경인에너지     부산 강서구 생곡로 40 (녹산동)   X :128.897647, Y :35.1248039
# 3      (주)고리길천주유소     부산 기장군 장안읍 해맞이로 487   X :129.289381, Y :35.3315196
# 4  (주)나부코직영 우원주유소  부산 영도구 태종로 181 (봉래동4가)   X :129.047706, Y :35.0948319
#
#            경도            위도
# 0  129.016910   35.1514817
# 1  129.100468    35.1248122
# 2  128.897647    35.1248039
# 3  129.289381    35.3315196
# 4  129.047706    35.0948319

# %% [markdown]
# #### 위경도 컬럼 제거

# %%
df = df.drop(columns='위경도')
df.head()
# Out:
#                상호                      주소          경도            위도
# 0      (주)개금태화주유소        부산 부산진구 가야대로 402  129.016910   35.1514817
# 1         (주)경인석유     부산 남구 신선로 448 (용당동)  129.100468    35.1248122
# 2        (주)경인에너지     부산 강서구 생곡로 40 (녹산동)  128.897647    35.1248039
# 3      (주)고리길천주유소     부산 기장군 장안읍 해맞이로 487  129.289381    35.3315196
# 4  (주)나부코직영 우원주유소  부산 영도구 태종로 181 (봉래동4가)  129.047706    35.0948319

# %% [markdown]
# #### 주유소_유가_데이터_NaN제외 csv파일 가져오기

# %%
data = pd.read_csv('./data/부산시 주유소 유가 데이터(20220209-20220809).csv', encoding='utf-8')
data.head()
# Out:
#          번호      지역                상호                     주소        기간     상표  \
# 0  A0033158  부산 강서구  (주)DJS신항만물류단지주유소  부산 강서구 가락대로 834 (범방동)  20220214  S-OIL
# 1  A0033158  부산 강서구  (주)DJS신항만물류단지주유소  부산 강서구 가락대로 834 (범방동)  20220215  S-OIL
# 2  A0033158  부산 강서구  (주)DJS신항만물류단지주유소  부산 강서구 가락대로 834 (범방동)  20220216  S-OIL
# 3  A0033158  부산 강서구  (주)DJS신항만물류단지주유소  부산 강서구 가락대로 834 (범방동)  20220217  S-OIL
# 4  A0033158  부산 강서구  (주)DJS신항만물류단지주유소  부산 강서구 가락대로 834 (범방동)  20220218  S-OIL
#
#   셀프여부   휘발유    경유
# 0   셀프  1638  1508
# 1   셀프  1638  1518
# 2   셀프  1668  1518
# 3   셀프  1678  1528
# 4   셀프  1678  1538

# %% [markdown]
# #### 필요한 컬럼값들로 구성된 데이터를 만들어서 중복되는 값을 제거

# %%
columns = ['상호', '셀프여부', '상표']
data_get = data[columns].copy()
data_get = data_get.drop_duplicates(subset=None, keep='first', ignore_index=False)
data_get
# Out:
#                         상호 셀프여부      상표
# 0         (주)DJS신항만물류단지주유소   셀프   S-OIL
# 177               (주)경인에너지   일반   S-OIL
# 354        (주)만은에너지 대사리주유소   셀프   GS칼텍스
# 531               (주)범방주유소   일반   SK에너지
# 708           (주)비에스이강동주유소   셀프  현대오일뱅크
# ...                    ...  ...     ...
# 66715                해변주유소   셀프   SK에너지
# 66892               해운대주유소   셀프   S-OIL
# 67069  현대오일뱅크(주)직영 장산IC주유소   일반   GS칼텍스
# 67173  현대오일뱅크(주)직영 장산IC주유소   일반  현대오일뱅크
# 67234    현대오일뱅크㈜직영 센텀셀프주유소   셀프  현대오일뱅크
#
# [397 rows x 3 columns]

# %% [markdown]
# #### df, data_get 데이터를 merge로 합친다

# %%
all_data = pd.merge(df, data_get, how='inner')
all_data
# Out:
#                       상호                      주소          경도            위도  \
# 0             (주)개금태화주유소        부산 부산진구 가야대로 402  129.016910   35.1514817
# 1                (주)경인석유     부산 남구 신선로 448 (용당동)  129.100468    35.1248122
# 2               (주)경인에너지     부산 강서구 생곡로 40 (녹산동)  128.897647    35.1248039
# 3             (주)고리길천주유소     부산 기장군 장안읍 해맞이로 487  129.289381    35.3315196
# 4         (주)나부코직영 우원주유소  부산 영도구 태종로 181 (봉래동4가)  129.047706    35.0948319
# ..                   ...                     ...         ...           ...
# 393      SK에너지(주)신광셀프주유소     부산 북구 덕천로 275 (만덕동)  129.034087    35.2098781
# 394       SK에너지(주)신도시주유소     부산 해운대구 대천로 82 (좌동)  129.171720    35.1735968
# 395    SK에너지(주)직영 태종로주유소    부산 영도구 태종로 290 (청학동)  129.057642    35.0979530
# 396  SK에너지(주)직영 해운대센텀주유소      부산 해운대구 수영강변대로 276  129.119134   35.1835484
# 397             YK에너지(주)     부산 남구 신선로 387 (용당동)  129.097491   35.1203309
#
#     셀프여부     상표
# 0     셀프  SK에너지
# 1     셀프  SK에너지
# 2     일반  S-OIL
# 3     일반  S-OIL
# 4     일반  SK에너지
# ..   ...    ...
# 393   셀프  SK에너지
# 394   셀프  SK에너지
# 395   셀프  SK에너지
# 396   셀프  SK에너지
# 397   셀프  SK에너지
#
# [398 rows x 6 columns]

# %%
data_get.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 397 entries, 0 to 67234
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   상호      397 non-null    object
#  1   셀프여부    397 non-null    object
#  2   상표      397 non-null    object
# dtypes: object(3)
# memory usage: 12.4+ KB

# %% [markdown]
# #### 부산 주유소 위치 시각화

# %%
map = folium.Map(location=[35.160389, 129.043961], zoom_start=10)

for i in all_data.index:
    sub_lat = all_data.loc[i, '위도']
    sub_long = all_data.loc[i, '경도']
    
    title = f"{all_data.loc[i, '상호']} - {all_data.loc[i, '주소']}"
    
    folium.CircleMarker(location=[sub_lat, sub_long],
                        radius=3,
                        tooltip=title).add_to(map)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5e0bfc59b4621c9f1384f46990b23265 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5e0bfc59b4621c9f1384f46990b23265&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_5e0bfc59b4621c9f1384f46990b23265 = L.map(
#                 &quot;map_5e0bfc59b4621c9f1384f46990b23265&quot;,
#                 {
#                     center: [35.160389, 129.043961],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_3e74581ac48321e92b5a44c0803d8f11 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_5e0bfc59b4621c9f1384f46990b23265);
#
#
#             var circle_marker_bad8620195739994acb89966e68423e2 = L.circleMarker(
#                 [35.1514817, 129.01691],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_5e0bfc59b4621c9f1384f46990b23265);
#
#
#             circle_marker_bad8620195739994acb89966e68423e2.bindTooltip(
#                 `&lt;div&gt;
#                      (주)개금태화주유소 - 부산 부산진구 가야대로 402
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var circle_marker_8075593f9fd33e87148a9e2dd7691c0a = L.circleMarker(
#                 [35.1248122, 129.100468],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_5e0bfc59b4621c9f1384f46990b23265);
#
#
#             circle_marker_8075593f9fd33e87148a9e2dd7691c0a.bindTooltip(
#                 `&lt;div&gt;
#                      (주)경인석유 - 부산 남구 신선로 448 (용당동)
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var circle_marker_7c87afded6bc8ce44a9261ac657189a2 = L.circleMarker(
#                 [35.1248039, 128.897647],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_5e0bfc59b4621c9f1384f46990b23265);
#
#
#             circle_marker_7c87afded6bc8ce44a9261ac657189a2.bindTooltip(
#                 `&lt;div&gt;
#                      (주)경인에너지 - 부산 강서구 생곡로 40 (녹산동)
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var circle_marker_4100ae2f50dd712b4396a5324652471d = L.circleMarker(
#                 [35.3315196, 129.289381],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_5e0bfc59b4621c9f1384f46990b23265);
#
#
#             circle_marker_4100ae2f50dd712b4396a5324652471d.bindTooltip(
#                 `&lt;div&gt;
#                      (주)고리길천주유소 - 부산 기장군 장안읍 해맞이로 487
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var circle_marker_28d71d122339ff67e7d783a328a66fdc = L.circleMarker(
#                 [35.0948319, 129.047706],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot

# %%
fig, ax = plt.subplots(1, 2, figsize=(10, 5), dpi=100, facecolor='white')

count_df = data_get[['상호','상표','셀프여부']].drop_duplicates()

size = count_df['셀프여부'].value_counts()
labels = count_df['셀프여부'].value_counts().index
colors = plt.cm.Pastel1(np.linspace(0, 1, 4))
explode = [0.01, 0.01]

ax[0].pie(size, labels=labels, colors=colors, shadow=True, startangle=45, explode=explode,autopct='%.1f%%')
ax[0].set_title('셀프여부 데이터 분포',fontsize=20)
ax[0].legend()

size = count_df['상표'].value_counts()
labels = count_df['상표'].value_counts().index
colors=plt.cm.Paired(np.linspace(0,1,count_df['상표'].value_counts().shape[0]))
explode = [0,0,0,0,0,0.1,0.2]

ax[1].pie(size, labels=labels, colors=colors, shadow=True, startangle=45, explode=explode,autopct='%.1f%%')
ax[1].set_title('상표별 데이터 분포',fontsize=20)
ax[1].legend()


plt.tight_layout()
plt.show()

# %% [markdown]
# #### 셀프여부

# %%
all_data['셀프여부'].value_counts()
# Out:
# 셀프    279
# 일반    119
# Name: 셀프여부, dtype: int64

# %%
sns.countplot(data=all_data, x='셀프여부')
# Out:
# <AxesSubplot:xlabel='셀프여부', ylabel='count'>

# %%
map = folium.Map(location=[35.160389, 129.043961], zoom_start=10)

for i in all_data.index:
    sub_lat = all_data.loc[i, '위도']
    sub_long = all_data.loc[i, '경도']
    
    title = f"{all_data.loc[i, '상호']} - {all_data.loc[i, '셀프여부']}"
    
    color = 'blue'
    if all_data.loc[i, '셀프여부'] == '일반':
        color = 'orange'

    
    folium.CircleMarker(location=[sub_lat, sub_long],
                        radius=2,
                        color=color,
                        tooltip=title).add_to(map)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a64585bfcd58fcf8156dd703dd2ec655 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a64585bfcd58fcf8156dd703dd2ec655&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_a64585bfcd58fcf8156dd703dd2ec655 = L.map(
#                 &quot;map_a64585bfcd58fcf8156dd703dd2ec655&quot;,
#                 {
#                     center: [35.160389, 129.043961],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_6fc14a7525783c818597b7a8691005c5 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_a64585bfcd58fcf8156dd703dd2ec655);
#
#
#             var circle_marker_e3c87e79469e0ecf0cb093af3aeb9032 = L.circleMarker(
#                 [35.1514817, 129.01691],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_a64585bfcd58fcf8156dd703dd2ec655);
#
#
#             circle_marker_e3c87e79469e0ecf0cb093af3aeb9032.bindTooltip(
#                 `&lt;div&gt;
#                      (주)개금태화주유소 - 셀프
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var circle_marker_3ec94fd4e1dca58d28edabb1d4c179c5 = L.circleMarker(
#                 [35.1248122, 129.100468],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_a64585bfcd58fcf8156dd703dd2ec655);
#
#
#             circle_marker_3ec94fd4e1dca58d28edabb1d4c179c5.bindTooltip(
#                 `&lt;div&gt;
#                      (주)경인석유 - 셀프
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var circle_marker_9754c34c22e88399b9decd16891a1a22 = L.circleMarker(
#                 [35.1248039, 128.897647],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;orange&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;orange&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_a64585bfcd58fcf8156dd703dd2ec655);
#
#
#             circle_marker_9754c34c22e88399b9decd16891a1a22.bindTooltip(
#                 `&lt;div&gt;
#                      (주)경인에너지 - 일반
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var circle_marker_c54f5f04fd3d193fd8dfb377b5f2dcb6 = L.circleMarker(
#                 [35.3315196, 129.289381],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;orange&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;orange&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_a64585bfcd58fcf8156dd703dd2ec655);
#
#
#             circle_marker_c54f5f04fd3d193fd8dfb377b5f2dcb6.bindTooltip(
#                 `&lt;div&gt;
#                      (주)고리길천주유소 - 일반
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var circle_marker_c1860811fc0a105e9744de0d7cdda58b = L.circleMarker(
#                 [35.0948319, 129.047706],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;orange&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;orange&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&

# %% [markdown]
# #### 상표별

# %%
map = folium.Map(location=[35.160389, 129.043961], zoom_start=10)

for i in all_data.index:
    sub_lat = all_data.loc[i, '위도']
    sub_long = all_data.loc[i, '경도']
    
    tooltip = f"{all_data['상호'].iloc[i]} - {all_data['상표'].iloc[i]}"
    # iframe = folium.IFrame(f"{all_data['상호'].iloc[i]} <br> {all_data['상표'].iloc[i]}")
    # popup = folium.Popup(iframe, min_width=200, max_width=100)
    
    color = 'purple'
    if all_data.loc[i, '상표'] == 'SK에너지':
        color = 'red'
    if all_data.loc[i, '상표'] == 'GS칼텍스':
        color = 'green'
    if all_data.loc[i, '상표'] == '현대오일뱅크':
        color = 'blue'
    if all_data.loc[i, '상표'] == 'S-OIL':
        color = 'yellow'
    if all_data.loc[i, '상표'] == '알뜰주유소':
        color = 'orange'
    if all_data.loc[i, '상표'] == '자가상표':
        color = 'black'
    
    folium.Marker(location=[sub_lat, sub_long],
                        icon=folium.Icon(color=color,icon='tint'), tooltip=tooltip).add_to(map)
map
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_13208\1206878070.py:26: UserWarning: color argument of Icon should be one of: {'darkpurple', 'blue', 'purple', 'red', 'green', 'lightred', 'darkblue', 'orange', 'lightgray', 'cadetblue', 'gray', 'darkred', 'lightgreen', 'white', 'beige', 'darkgreen', 'pink', 'lightblue', 'black'}.
#   icon=folium.Icon(color=color,icon='tint'), tooltip=tooltip).add_to(map)
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9f9b2db68f82364b71d9e8301fb685ec {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9f9b2db68f82364b71d9e8301fb685ec&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_9f9b2db68f82364b71d9e8301fb685ec = L.map(
#                 &quot;map_9f9b2db68f82364b71d9e8301fb685ec&quot;,
#                 {
#                     center: [35.160389, 129.043961],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_acb9d572eff710c01a3cc3d68a69eef2 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_9f9b2db68f82364b71d9e8301fb685ec);
#
#
#             var marker_904b0758865569f19275324af92f4461 = L.marker(
#                 [35.1514817, 129.01691],
#                 {}
#             ).addTo(map_9f9b2db68f82364b71d9e8301fb685ec);
#
#
#             var icon_e58ae1423d32657a9e8feeba6c10e84c = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;tint&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_904b0758865569f19275324af92f4461.setIcon(icon_e58ae1423d32657a9e8feeba6c10e84c);
#
#
#             marker_904b0758865569f19275324af92f4461.bindTooltip(
#                 `&lt;div&gt;
#                      (주)개금태화주유소 - SK에너지
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_b27cf4cd2a379e098c5ae517e6a36aba = L.marker(
#                 [35.1248122, 129.100468],
#                 {}
#             ).addTo(map_9f9b2db68f82364b71d9e8301fb685ec);
#
#
#             var icon_7487ac2430edb280e8d5cdc709f7b222 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;tint&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_b27cf4cd2a379e098c5ae517e6a36aba.setIcon(icon_7487ac2430edb280e8d5cdc709f7b222);
#
#
#             marker_b27cf4cd2a379e098c5ae517e6a36aba.bindTooltip(
#                 `&lt;div&gt;
#                      (주)경인석유 - SK에너지
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_f6d6b3790574363c65faa048a6d0acaf = L.marker(
#                 [35.1248039, 128.897647],
#                 {}
#             ).addTo(map_9f9b2db68f82364b71d9e8301fb685ec);
#
#
#             var icon_5543e4fd0c177aa3d75d5ea2575ee379 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;tint&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;yellow&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_f6d6b3790574363c65faa048a6d0acaf.setIcon(icon_5543e4fd0c177aa3d75d5ea2575ee379);
#
#
#             marker_f6d6b3790574363c65faa048a6d0acaf.bindTooltip(
#                 `&lt;div&gt;
#                      (주)경인에너지 - S-OIL
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_c2f5829f2dca249e67a01101b4cbb74b = L.marker(
#                 [35.3315196, 129.289381],
#                 {}
#             ).addTo(map_9f9b2db68f82364b71d9e8301fb685ec);
#
#
#             var icon_bf1ac65b50eb58c34f2588cf16f8351e = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;tint&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;yellow&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_c2f5829f2dca249e67a01101b4cbb74b.setIcon(icon_bf1ac65b50eb58c34f2588cf16f8351e);
#
#
#             marker_c2f5829f2dca249e67a01101b4cbb74b.bindTooltip(
#                 `&lt;div&gt;
#                      (주)고리길천주유소 - S-OIL
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_92523e6b48383c5a2ec93dba8cc0fecd = L.marker(
#                 [35.0948319, 129.047706],
#                 {}
#             ).addTo(map_9f9b2db68f82364b71d9e8301fb685ec);
#
#
#             var icon_1fcaa65bbcdfc386e155ede2d94a1813 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;tint&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_92523e6b48383c5a2ec93dba8cc0fecd.setIcon(icon_1fcaa65bbcdfc386e155ede2d94a1813);
#
#
#             marker_92523e6b48383c5a2ec93dba8cc0fecd.bindTooltip(

# %% [markdown]
# ####  네이버 검색량

# %%
data_N = pd.read_excel('./data/naver-2022-8-12-기름값.xlsx')
data_N
# Out:
#    기름값 Total 64      검색량  총클릭수     트렌드    문서수     비율  포스팅순위 첫번째 섹션 두번째 섹션
# 0           기름값   214300     8   -6.91  11556   0.05    NaN   플레이스     뉴스
# 1          국제유가  1334100   744    9.83  11167   0.01    NaN   증권정보     뉴스
# 2        주유소기름값    11100     0   11.59   1362   0.12    NaN   플레이스     뉴스
# 3         기름값인하    17940     0   -6.78    818   0.05    NaN     뉴스   지식iN
# 4         기름값싼곳    12850     0  359.51    522   0.04    NaN   플레이스   VIEW
# ..          ...      ...   ...     ...    ...    ...    ...    ...    ...
# 59      미국기름값폭등       20     0    0.00    222  11.10    NaN     통합   VIEW
# 60      미국기름값추이       20     0    0.00     59   2.95    NaN    동영상   VIEW
# 61    미국기름값2022       20     0    0.00    475  23.75    NaN     통합   VIEW
# 62    한국미국기름값차이       20     0    0.00    141   7.05    NaN   VIEW    동영상
# 63      미국기름값전망       20     0    0.00    532  26.60    NaN   VIEW     통합
#
# [64 rows x 9 columns]

# %%
columns = ['기름값 Total 64', '검색량']
data_N = data_N[columns].copy()
data_N.rename(columns={'기름값 Total 64' : '키워드'}, inplace=True)
data_N.head()
# Out:
#       키워드      검색량
# 0     기름값   214300
# 1    국제유가  1334100
# 2  주유소기름값    11100
# 3   기름값인하    17940
# 4   기름값싼곳    12850

# %% [markdown]
# #### 유튜브 검색량

# %%
data_Y = pd.read_excel('./data/youtube2022-8-12-기름 값.xlsx')
data_Y
# Out:
#     기름 값 Total 79   검색량     영상수     비율    트렌드
# 0            기름 값  8100  167526  20.68 -33.11
# 1     기름 값 오르는 이유   880    1225   1.39 -68.95
# 2         기름 값 전망   480    3751   7.82 -44.62
# 3         기름 값 인하   590    1912   3.24   0.00
# 4         기름 값 폭등    90    1472  16.36 -58.82
# ..            ...   ...     ...    ...    ...
# 74       원유 가격 전망   320    3408  10.65 -33.33
# 75  국제 유가 전망 2021   110     790   7.18 -66.67
# 76     100km 기름 값   110     366   3.33   0.00
# 77        기름 값 싼곳    50      52   1.04  75.00
# 78      휘발유 가격 추이   320     111   0.35 -45.83
#
# [79 rows x 5 columns]

# %%
columns = ['기름 값 Total 79', '검색량']
data_Y = data_Y[columns].copy()
data_Y.rename(columns={'기름 값 Total 79' : '키워드'}, inplace=True)
data_Y.head()
# Out:
#            키워드   검색량
# 0         기름 값  8100
# 1  기름 값 오르는 이유   880
# 2      기름 값 전망   480
# 3      기름 값 인하   590
# 4      기름 값 폭등    90

# %% [markdown]
# #### 네이버 검색량/ 유튜브 검색량 csv파일 합치기

# %%
data = pd.concat([data_N, data_Y], ignore_index=True)
data
# Out:
#                키워드      검색량
# 0              기름값   214300
# 1             국제유가  1334100
# 2           주유소기름값    11100
# 3            기름값인하    17940
# 4            기름값싼곳    12850
# ..             ...      ...
# 138       원유 가격 전망      320
# 139  국제 유가 전망 2021      110
# 140     100km 기름 값      110
# 141        기름 값 싼곳       50
# 142      휘발유 가격 추이      320
#
# [143 rows x 2 columns]

# %% [markdown]
# #### DataFrame -> dic으로 변환

# %%
data = data.set_index('키워드').to_dict()['검색량']
data
# Out:
# {'기름값': 214300,
#  '국제유가': 1334100,
#  '주유소기름값': 11100,
#  '기름값인하': 17940,
#  '기름값싼곳': 12850,
#  '기름값계산기': 25160,
#  '기름값계산': 3790,
#  '구미기름값': 4860,
#  '기름값전망': 4070,
#  '대구기름값': 5930,
#  '부산기름값': 3880,
#  '100KM기름값': 2380,
#  '기름값계산기네이버': 4300,
#  '유류': 4080,
#  '연료비': 500,
#  '미국기름값': 2780,
#  '기름': 7450,
#  '교통비': 6160,
#  '식비': 4130,
#  '지불하다': 1330,
#  '유지비': 430,
#  '기름값비교사이트': 20,
#  '기름값싼주유소': 100,
#  '기름값인하시기': 20,
#  '기름값인상': 490,
#  '기름값오르는이유': 120,
#  '기름값할인카드': 340,
#  '기름값추이': 590,
#  '기름값인상이유': 180,
#  '기름값3000원': 30,
#  '기름값세금': 150,
#  '미국기름값리터당': 20,
#  '기름값계산법': 40,
#  '기름값시세': 260,
#  '주행거리기름값계산': 30,
#  '미국기름값오르는이유': 20,
#  '기름값오르는이유러시아': 20,
#  '거리기름값계산': 70,
#  '기름값톨비계산': 20,
#  '한달기름값계산': 20,
#  '쏘카기름값계산': 20,
#  '미국기름값계산': 20,
#  '기름값인하유류세': 20,
#  '기름값인하이유': 180,
#  '유류비계산기름값': 20,
#  '여행기름값계산': 30,
#  '기름값인하효과': 20,
#  '11월기름값인하': 20,
#  '국내기름값추이': 20,
#  '최근기름값인하': 20,
#  '기름값상승이유': 60,
#  '기름값변동추이': 20,
#  '기름값상승률': 20,
#  '기름값상승세': 20,
#  '기름값상승해결방안': 20,
#  '기름값상승주식': 20,
#  '기름값상승원인': 40,
#  '기름값상승물가': 20,
#  '미국기름값2021': 20,
#  '미국기름값폭등': 20,
#  '미국기름값추이': 20,
#  '미국기름값2022': 20,
#  '한국미국기름값차이': 20,
#  '미국기름값전망': 20,
#  '기름 값': 8100,
#  '기름 값 오르는 이유': 880,
#  '기름 값 전망': 480,
#  '기름 값 인하': 590,
#  '기름 값 폭등': 90,
#  '기름 값 상승': 110,
#  '기름 값 제일 싼 주유소': 10,
#  '기름 값 인상': 110,
#  '기름 값 오른 이유': 10,
#  '한국 기름 값': 140,
#  '서울 기름 값': 170,
#  '미국 기름 값': 480,
#  '기름 값 계산기': 390,
#  '기름 값 추이': 140,
#  'Km 당 기름 값': 40,
#  '휘발유 리터당 가격': 1300,
#  '기름 값 어플': 20,
#  '주유소 가격': 2400,
#  'Lpg 리터당 가격': 480,
#  '경유 리터당 가격': 590,
#  '지역별 휘발유 가격': 2400,
#  '가까운 주유소 가격': 720,
#  '기름 가격': 260,
#  '주유소 휘발유 가격': 110,
#  '주변 주유소 가격': 260,
#  '주유소 기름': 70,
#  '근처 주유소 가격': 320,
#  '제일 싼 주유소': 70,
#  '주유소 기름 가격': 50,
#  '기름 싼곳': 30,
#  '실시간 주유소 가격': 20,
#  '휘발유 가격 싼 주유소': 20,
#  '기름 싼 주유소': 10,
#  '주유소 제일 싼곳': 20,
#  '휘발유 가격': 4400,
#  '기름 값 상승 이유': 50,
#  '기름 만땅': 40,
#  '기름 값 이 오르는 이유': 40,
#  '미국 기름 값 리터당': 70,
#  '오늘 휘발유 리터당 가격': 390,
#  '휘발유 가격 전망': 210,
#  '2022 휘발유 가격': 70,
#  '주유소 가격 검색': 1000,
#  '오늘 경유 가격': 720,
#  '2021 휘발유 가격': 90,
#  '주유 어플': 20,
#  '기름 값 싼 주유소': 110,
#  '기름 값 비교': 90,
#  '유가 상승 원인': 320,
#  '경유 가격': 2400,
#  '등유 가격': 1000,
#  '경유 가격 인상 이유': 50,
#  '국제 유가 상승 원인': 90,
#  '국제 유가 장기 전망': 260,
#  '유가 전망': 1600,
#  '국제 유가 전망': 720,
#  '오늘 휘발유 가격': 880,
#  '휘발유 가격 그래프': 170,
#  '현재 휘발유 가격': 70,
#  '셀프 주유소 가격': 390,
#  '농협 주유소 가격': 590,
#  '주유소 가격 비교': 260,
#  '유류 계산기': 70,
#  '유류비 계산기': 390,
#  '1km 당 기름 값': 50,
#  '200km 기름 값': 90,
#  '주유 계산기': 40,
#  '10km 기름 값': 30,
#  '원유 가격 전망': 320,
#  '국제 유가 전망 2021': 110,
#  '100km 기름 값': 110,
#  '기름 값 싼곳': 50,
#  '휘발유 가격 추이': 320}

# %%
wc = WordCloud(font_path=font_path, background_color='#f5f5f5', width=1040, height=700)
cloud = wc.generate_from_frequencies(data)

plt.figure(figsize=(40,15))
plt.imshow(cloud)
plt.axis('off')
plt.show()

# %% [markdown]
# #### 검색량이 가장 많은 단어 **국제유가**에 대해 알아보자!

# %%
def get_oil_price(code):
    delay = 0.01
    page = 1
    result = []
    start_time = datetime.now()
    
    # 수집
    print('[{}] 데이터 수집을 시작합니다. (code: {})'.format(start_time.strftime('%Y/%m/%d %H:%M:%S'), code))
    while(True):
        url = 'https://finance.naver.com/marketindex/worldDailyQuote.nhn?marketindexCd={}&fdtc=2&page={}'.format(code, page)
        data = pd.read_html(url)[0].dropna()
        if page != 1:
            try:
                if data.iloc[-1, 0] == result[-1].iloc[-1, 0]:
                    break
            except:
                break
        result.append(data)
        page += 1
        if page == 20:
            break
        time.sleep(delay)
    
    # 가공
    oil_price = pd.concat(result).reset_index(drop=True)
    oil_price.columns = ['날짜', '종가', '전일대비', '등락율']
    oil_price['날짜'] = oil_price['날짜'].apply(lambda x: datetime.strptime(x, '%Y.%m.%d'))
    oil_price = oil_price[['날짜', '종가']]
    oil_price.insert(0, '코드', code)
    
    end_time = datetime.now()
    print('[{}] 데이터 수집을 종료합니다. (code: {}, 수집시간: {}초, 데이터수: {:,}개)'.format(end_time.strftime('%Y/%m/%d %H:%M:%S'), code, (end_time-start_time).seconds, len(oil_price)))
    return oil_price

# %% [markdown]
# ##### 두바이유

# %%
oil_price_du = get_oil_price('OIL_DU')
# Out:
# [2022/08/18 16:58:26] 데이터 수집을 시작합니다. (code: OIL_DU)
# [2022/08/18 16:58:28] 데이터 수집을 종료합니다. (code: OIL_DU, 수집시간: 2초, 데이터수: 133개)

# %%
du = oil_price_du[['날짜','종가']]
du.columns = ['날짜','두바이_종가']
du
# Out:
#             날짜  두바이_종가
# 0   2022-08-17   94.04
# 1   2022-08-16   93.46
# 2   2022-08-15   94.97
# 3   2022-08-12   96.48
# 4   2022-08-11   98.18
# ..         ...     ...
# 128 2022-02-11   91.79
# 129 2022-02-10   89.92
# 130 2022-02-09   89.88
# 131 2022-02-08   89.28
# 132 2022-02-07   90.76
#
# [133 rows x 2 columns]

# %% [markdown]
# #### 두바이유 가격 저장

# %%
import pandas as pd

# %%
du.to_csv("./data/국제유가(두바이)_주말제거.csv", encoding="utf-8", index=False)

# %% [markdown]
# ##### 서부텍사스유

# %%
oil_price_wti = get_oil_price('OIL_CL')
# Out:
# [2022/08/18 16:58:29] 데이터 수집을 시작합니다. (code: OIL_CL)
# [2022/08/18 16:58:31] 데이터 수집을 종료합니다. (code: OIL_CL, 수집시간: 1초, 데이터수: 133개)

# %%
wti = oil_price_wti[['날짜','종가']]
wti.columns = ['날짜','wti_종가']
wti
# Out:
#             날짜  wti_종가
# 0   2022-08-17   88.11
# 1   2022-08-16   86.53
# 2   2022-08-15   89.41
# 3   2022-08-12   92.09
# 4   2022-08-11   94.34
# ..         ...     ...
# 128 2022-02-11   93.10
# 129 2022-02-10   89.88
# 130 2022-02-09   89.66
# 131 2022-02-08   89.36
# 132 2022-02-07   91.32
#
# [133 rows x 2 columns]

# %% [markdown]
# ##### 브렌트유

# %%
oil_price_brent = get_oil_price('OIL_BRT')
# Out:
# [2022/08/18 16:58:31] 데이터 수집을 시작합니다. (code: OIL_BRT)
# [2022/08/18 16:58:33] 데이터 수집을 종료합니다. (code: OIL_BRT, 수집시간: 2초, 데이터수: 133개)

# %%
brent = oil_price_brent[['날짜','종가']]
brent.columns = ['날짜','브렌트_종가']
brent
# Out:
#             날짜  브렌트_종가
# 0   2022-08-17   93.65
# 1   2022-08-16   92.34
# 2   2022-08-15   95.10
# 3   2022-08-12   98.15
# 4   2022-08-11   99.60
# ..         ...     ...
# 128 2022-02-17   92.97
# 129 2022-02-16   94.81
# 130 2022-02-15   93.28
# 131 2022-02-14   96.48
# 132 2022-02-11   94.44
#
# [133 rows x 2 columns]

# %%
plt.figure(figsize=(10.5,5))
plt.plot(oil_price_du['날짜'], oil_price_du['종가'], label='두바이유')
plt.plot(oil_price_brent['날짜'], oil_price_brent['종가'], label='브렌트유')
plt.plot(oil_price_wti['날짜'], oil_price_wti['종가'], label='WTI')

plt.title('유가 추이')
plt.xlabel('기준일자')
plt.ylabel('가격(USD/배럴)')
plt.legend()
plt.tight_layout()
plt.show()
